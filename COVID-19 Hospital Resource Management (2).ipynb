# %% [markdown]
# # COVID-19 Hospital Resource Management
# ## Data Mining - VU Amsterdam
# ### Authors: Kimberley Boersma, Selma Muhammad, Neil Mizzi - Group 26

# %%
# Imports
import os
import pandas as pd

# %% [markdown]
# Load JHU data

# %%
# Get Time-Series Data of cases as Pandas DataFrame
dir_jhu = '/kaggle/input/jhucovid19/csse_covid_19_data/csse_covid_19_daily_reports'
#files = [(os.path.join(dirname, filename) for filename in filenames if ('gitignore' not in filename and 'README' not in filename)) for dirname, _, filenames in os.walk(dir)]

df_list = []
for dirname, _, files in os.walk(dir_jhu):
    for file in files:
        if 'gitignore' not in file and 'README' not in file:
            full_dir = os.path.join(dirname, file)
            #print(full_dir)
            df_list.append(pd.read_csv(full_dir))
jhu_df = pd.concat(df_list, axis=0, ignore_index=True, sort=True)

# trying out some basic analysis
malta = jhu_df['Country/Region'] == 'US'
cnt = 0
for x in malta:
    cnt += 1 if x else 0
cnt
# Out:
#        Active Admin2 Combined_Key  Confirmed  Country/Region Country_Region  \
# 0         NaN    NaN          NaN        1.0  Mainland China            NaN
# 1         NaN    NaN          NaN       14.0  Mainland China            NaN
# 2         NaN    NaN          NaN        6.0  Mainland China            NaN
# 3         NaN    NaN          NaN        1.0  Mainland China            NaN
# 4         NaN    NaN          NaN        NaN  Mainland China            NaN
# ...       ...    ...          ...        ...             ...            ...
# 86427     NaN    NaN          NaN        1.0              US            NaN
# 86428     NaN    NaN          NaN        1.0              US            NaN
# 86429     NaN    NaN          NaN        1.0              US            NaN
# 86430     NaN    NaN          NaN        1.0              US            NaN
# 86431     NaN    NaN          NaN        1.0              US            NaN
#
#        Deaths  FIPS      Last Update Last_Update  Lat  Latitude  Long_  \
# 0         NaN   NaN  1/22/2020 17:00         NaN  NaN       NaN    NaN
# 1         NaN   NaN  1/22/2020 17:00         NaN  NaN       NaN    NaN
# 2         NaN   NaN  1/22/2020 17:00         NaN  NaN       NaN    NaN
# 3         NaN   NaN  1/22/2020 17:00         NaN  NaN       NaN    NaN
# 4         NaN   NaN  1/22/2020 17:00         NaN  NaN       NaN    NaN
# ...       ...   ...              ...         ...  ...       ...    ...
# 86427     0.0   NaN   2/1/2020 19:53         NaN  NaN       NaN    NaN
# 86428     0.0   NaN   2/1/2020 19:53         NaN  NaN       NaN    NaN
# 86429     0.0   NaN   2/1/2020 19:53         NaN  NaN       NaN    NaN
# 86430     0.0   NaN   2/1/2020 19:43         NaN  NaN       NaN    NaN
# 86431     0.0   NaN   2/1/2020 19:43         NaN  NaN       NaN    NaN
#
#        Longitude   Province/State Province_State  Recovered
# 0            NaN            Anhui            NaN        NaN
# 1            NaN          Beijing            NaN        NaN
# 2            NaN        Chongqing            NaN        NaN
# 3            NaN           Fujian            NaN        NaN
# 4            NaN            Gansu            NaN        NaN
# ...          ...              ...            ...        ...
# 86427        NaN  Los Angeles, CA            NaN        0.0
# 86428        NaN       Orange, CA            NaN        0.0
# 86429        NaN  Santa Clara, CA            NaN        0.0
# 86430        NaN      Seattle, WA            NaN        0.0
# 86431        NaN        Tempe, AZ            NaN        0.0
#
# [86432 rows x 17 columns]

# %% [markdown]
# Getting IHMES data

# %%
dir_ihmes = '/kaggle/input/ihmes-covid19-projections/2020_04_12.02/Hospitalization_all_locs.csv'
df_ihmes = pd.read_csv(dir_ihmes)

df_ihmes
